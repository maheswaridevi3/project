# %% [markdown]
# <a href="https://colab.research.google.com/github/maheswaridevi3/project/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/kidney_disease.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             391 non-null    float64
#  2   bp              388 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             330 non-null    object
# ...

# %%
df.describe()
# Out:
#                id         age          bp          sg          al          su  \
# count  400.000000  391.000000  388.000000  353.000000  354.000000  351.000000
# mean   199.500000   51.483376   76.469072    1.017408    1.016949    0.450142
# std    115.614301   17.169714   13.683637    0.005717    1.352679    1.099191
# min      0.000000    2.000000   50.000000    1.005000    0.000000    0.000000
# 25%     99.750000   42.000000   70.000000    1.010000    0.000000    0.000000
# 50%    199.500000   55.000000   80.000000    1.020000    0.000000    0.000000
# 75%    299.250000   64.500000   80.000000    1.020000    2.000000    0.000000
# max    399.000000   90.000000  180.000000    1.025000    5.000000    5.000000
#
#               bgr          bu          sc         sod         pot        hemo
# count  356.000000  381.000000  383.000000  313.000000  312.000000  348.000000
# mean   148.036517   57.425722    3.072454  137.528754    4.627244   12.526437
# ...

# %%
numeric_cols = df.select_dtypes(include=['float64']).columns

# %%
numeric_cols
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo'], dtype='object')

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy='mean')
df[numeric_cols] = imputer.fit_transform(df[numeric_cols])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             400 non-null    float64
#  2   bp              400 non-null    float64
#  3   sg              400 non-null    float64
#  4   al              400 non-null    float64
#  5   su              400 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             400 non-null    float64
#  11  bu              400 non-null    float64
#  12  sc              400 non-null    float64
#  13  sod             400 non-null    float64
#  14  pot             400 non-null    float64
#  15  hemo            400 non-null    float64
#  16  pcv             330 non-null    object
# ...

# %%
df['classification'].unique()
# Out:
# array(['ckd', 'ckd\t', 'notckd'], dtype=object)

# %%
df.head(50)
# Out:
#     id        age          bp        sg        al        su       rbc  \
# 0    0  48.000000   80.000000  1.020000  1.000000  0.000000       NaN
# 1    1   7.000000   50.000000  1.020000  4.000000  0.000000       NaN
# 2    2  62.000000   80.000000  1.010000  2.000000  3.000000    normal
# 3    3  48.000000   70.000000  1.005000  4.000000  0.000000    normal
# 4    4  51.000000   80.000000  1.010000  2.000000  0.000000    normal
# 5    5  60.000000   90.000000  1.015000  3.000000  0.000000       NaN
# 6    6  68.000000   70.000000  1.010000  0.000000  0.000000       NaN
# 7    7  24.000000   76.469072  1.015000  2.000000  4.000000    normal
# 8    8  52.000000  100.000000  1.015000  3.000000  0.000000    normal
# 9    9  53.000000   90.000000  1.020000  2.000000  0.000000  abnormal
# 10  10  50.000000   60.000000  1.010000  2.000000  4.000000       NaN
# 11  11  63.000000   70.000000  1.010000  3.000000  0.000000  abnormal
# ...

# %%
df['rc'].unique()
# Out:
# array(['5.2', nan, '3.9', '4.6', '4.4', '5', '4.0', '3.7', '3.8', '3.4',
#        '2.6', '2.8', '4.3', '3.2', '3.6', '4', '4.1', '4.9', '2.5', '4.2',
#        '4.5', '3.1', '4.7', '3.5', '6.0', '5.0', '2.1', '5.6', '2.3',
#        '2.9', '2.7', '8.0', '3.3', '3.0', '3', '2.4', '4.8', '\t?', '5.4',
#        '6.1', '6.2', '6.3', '5.1', '5.8', '5.5', '5.3', '6.4', '5.7',
#        '5.9', '6.5'], dtype=object)

# %%
df['htn'].unique()
# Out:
# array(['yes', 'no', nan], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             400 non-null    float64
#  2   bp              400 non-null    float64
#  3   sg              400 non-null    float64
#  4   al              400 non-null    float64
#  5   su              400 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             400 non-null    float64
#  11  bu              400 non-null    float64
#  12  sc              400 non-null    float64
#  13  sod             400 non-null    float64
#  14  pot             400 non-null    float64
#  15  hemo            400 non-null    float64
#  16  pcv             330 non-null    object
# ...

# %%
df['rbc'].unique()
# Out:
# array([nan, 'normal', 'abnormal'], dtype=object)

# %%
df['pc'].unique()
# Out:
# array(['normal', 'abnormal', nan], dtype=object)

# %%
df['pcc'].unique()
# Out:
# array(['notpresent', 'present', nan], dtype=object)

# %%
df['ba'].unique()
# Out:
# array(['notpresent', 'present', nan], dtype=object)

# %%
df['pcv'].unique()
# Out:
# array(['44', '38', '31', '32', '35', '39', '36', '33', '29', '28', nan,
#        '16', '24', '37', '30', '34', '40', '45', '27', '48', '\t?', '52',
#        '14', '22', '18', '42', '17', '46', '23', '19', '25', '41', '26',
#        '15', '21', '43', '20', '\t43', '47', '9', '49', '50', '53', '51',
#        '54'], dtype=object)

# %%
df['wc'].unique()
# Out:
# array(['7800', '6000', '7500', '6700', '7300', nan, '6900', '9600',
#        '12100', '4500', '12200', '11000', '3800', '11400', '5300', '9200',
#        '6200', '8300', '8400', '10300', '9800', '9100', '7900', '6400',
#        '8600', '18900', '21600', '4300', '8500', '11300', '7200', '7700',
#        '14600', '6300', '\t6200', '7100', '11800', '9400', '5500', '5800',
#        '13200', '12500', '5600', '7000', '11900', '10400', '10700',
#        '12700', '6800', '6500', '13600', '10200', '9000', '14900', '8200',
#        '15200', '5000', '16300', '12400', '\t8400', '10500', '4200',
#        '4700', '10900', '8100', '9500', '2200', '12800', '11200', '19100',
#        '\t?', '12300', '16700', '2600', '26400', '8800', '7400', '4900',
#        '8000', '12000', '15700', '4100', '5700', '11500', '5400', '10800',
#        '9900', '5200', '5900', '9300', '9700', '5100', '6600'],
#       dtype=object)

# %%
df['rc'].unique()
# Out:
# array(['5.2', nan, '3.9', '4.6', '4.4', '5', '4.0', '3.7', '3.8', '3.4',
#        '2.6', '2.8', '4.3', '3.2', '3.6', '4', '4.1', '4.9', '2.5', '4.2',
#        '4.5', '3.1', '4.7', '3.5', '6.0', '5.0', '2.1', '5.6', '2.3',
#        '2.9', '2.7', '8.0', '3.3', '3.0', '3', '2.4', '4.8', '\t?', '5.4',
#        '6.1', '6.2', '6.3', '5.1', '5.8', '5.5', '5.3', '6.4', '5.7',
#        '5.9', '6.5'], dtype=object)

# %%
df['htn'].unique()
# Out:
# array(['yes', 'no', nan], dtype=object)

# %%
df['appet'].unique()
# Out:
# array(['good', 'poor', nan], dtype=object)

# %%
df['dm'].unique()
# Out:
# array(['yes', 'no', ' yes', '\tno', '\tyes', nan], dtype=object)

# %%
df['cad'].unique()
# Out:
# array(['no', 'yes', '\tno', nan], dtype=object)

# %%
df['appet'].unique()
# Out:
# array(['good', 'poor', nan], dtype=object)

# %%
df['pe'].unique()
# Out:
# array(['no', 'yes', nan], dtype=object)

# %%
df['ane'].unique()
# Out:
# array(['no', 'yes', nan], dtype=object)

# %%
df['classification'].unique()
# Out:
# array(['ckd', 'ckd\t', 'notckd'], dtype=object)

# %%
df.dtypes
# Out:
# id                  int64
# age               float64
# bp                float64
# sg                float64
# al                float64
# su                float64
# rbc                object
# pc                 object
# pcc                object
# ba                 object
# bgr               float64
# bu                float64
# sc                float64
# sod               float64
# pot               float64
# hemo              float64
# pcv                object
# wc                 object
# rc                 object
# htn                object
# dm                 object
# cad                object
# appet              object
# pe                 object
# ane                object
# classification     object
# dtype: object

# %%
df['pcv'].replace({'\t?': np.nan}, inplace=True)

# %%
df['pcv'].unique()
# Out:
# array(['44', '38', '31', '32', '35', '39', '36', '33', '29', '28', nan,
#        '16', '24', '37', '30', '34', '40', '45', '27', '48', '52', '14',
#        '22', '18', '42', '17', '46', '23', '19', '25', '41', '26', '15',
#        '21', '43', '20', '\t43', '47', '9', '49', '50', '53', '51', '54'],
#       dtype=object)

# %%
pcv_mean = df['pcv'].astype('float').mean()

# %%
df['pcv'] = df['pcv'].replace({'\t43': '43'})

# %%
df['pcv'].unique()
# Out:
# array(['44', '38', '31', '32', '35', '39', '36', '33', '29', '28', nan,
#        '16', '24', '37', '30', '34', '40', '45', '27', '48', '52', '14',
#        '22', '18', '42', '17', '46', '23', '19', '25', '41', '26', '15',
#        '21', '43', '20', '47', '9', '49', '50', '53', '51', '54'],
#       dtype=object)

# %%
df.dtypes
# Out:
# id                  int64
# age               float64
# bp                float64
# sg                float64
# al                float64
# su                float64
# rbc                object
# pc                 object
# pcc                object
# ba                 object
# bgr               float64
# bu                float64
# sc                float64
# sod               float64
# pot               float64
# hemo              float64
# pcv                object
# wc                 object
# rc                 object
# htn                object
# dm                 object
# cad                object
# appet              object
# pe                 object
# ane                object
# classification     object
# dtype: object

# %%
avg_pcv = df['pcv'].astype('float').mean()

# %%
avg_rou =avg_pcv.round(2)

# %%
df.dtypes
# Out:
# id                  int64
# age               float64
# bp                float64
# sg                float64
# al                float64
# su                float64
# rbc                object
# pc                 object
# pcc                object
# ba                 object
# bgr               float64
# bu                float64
# sc                float64
# sod               float64
# pot               float64
# hemo              float64
# pcv                object
# wc                 object
# rc                 object
# htn                object
# dm                 object
# cad                object
# appet              object
# pe                 object
# ane                object
# classification     object
# dtype: object

# %%
df['pcv'].replace(np.nan, avg_rou,inplace=True)

# %%
df['pcv'].unique()
# Out:
# array(['44', '38', '31', '32', '35', '39', '36', '33', '29', '28',
#        38.88449848024316, '16', '24', '37', '30', '34', '40', '45', '27',
#        '48', '52', '14', '22', '18', '42', '17', '46', '23', '19', '25',
#        '41', '26', '15', '21', '43', '20', '47', '9', '49', '50', '53',
#        '51', '54'], dtype=object)

# %%
df['pcv'] = pd.to_numeric(df['pcv'], errors='coerce')

# %%
df.dtypes
# Out:
# id                  int64
# age               float64
# bp                float64
# sg                float64
# al                float64
# su                float64
# rbc                object
# pc                 object
# pcc                object
# ba                 object
# bgr               float64
# bu                float64
# sc                float64
# sod               float64
# pot               float64
# hemo              float64
# pcv               float64
# wc                 object
# rc                 object
# htn                object
# dm                 object
# cad                object
# appet              object
# pe                 object
# ane                object
# classification     object
# dtype: object
